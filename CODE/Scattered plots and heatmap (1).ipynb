# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dataset=pd.read_csv('C:/Users/Pari/Desktop/countries_clean5.csv')

# %%
dataset
# Out:
#              country  year     sex          age  suicide_no  population  \
# 0          Argentina  1990    male    75+ years         226      411100
# 1          Argentina  1990    male  55-74 years         502     2128000
# 2          Argentina  1990    male  35-54 years         439     3619000
# 3          Argentina  1990  female    75+ years          61      643000
# 4          Argentina  1990    male  25-34 years         182     2297000
# ...              ...   ...     ...          ...         ...         ...
# 11515  United States  2013  female  25-34 years        1285    20951958
# 11516  United States  2013  female  15-24 years         975    21698877
# 11517  United States  2013  female    75+ years         431    11486590
# 11518  United States  2013    male   5-14 years         252    21233001
# 11519  United States  2013  female   5-14 years         143    20308672
#
#        suicides_per_100k  HDI_for_year  gdp_for_year  gdp_per_capita  \
# ...

# %%
df=pd.DataFrame(dataset)

# %%
df
# Out:
#              country  year     sex          age  suicide_no  population  \
# 0          Argentina  1990    male    75+ years         226      411100
# 1          Argentina  1990    male  55-74 years         502     2128000
# 2          Argentina  1990    male  35-54 years         439     3619000
# 3          Argentina  1990  female    75+ years          61      643000
# 4          Argentina  1990    male  25-34 years         182     2297000
# ...              ...   ...     ...          ...         ...         ...
# 11515  United States  2013  female  25-34 years        1285    20951958
# 11516  United States  2013  female  15-24 years         975    21698877
# 11517  United States  2013  female    75+ years         431    11486590
# 11518  United States  2013    male   5-14 years         252    21233001
# 11519  United States  2013  female   5-14 years         143    20308672
#
#        suicides_per_100k  HDI_for_year  gdp_for_year  gdp_per_capita  \
# ...

# %%
df.sex.value_counts().plot(kind='bar')
plt.show()

# %%
df.age.value_counts().plot(kind='bar')
plt.show()

# %%
df.year.value_counts().plot(kind='bar')
plt.show()

# %%
df.country.value_counts().plot(kind='bar')
plt.show()

# %%
df.suicide_no.value_counts().plot(kind='bar')
plt.show()

# %%
df.HDI_for_year.value_counts().plot(kind='bar')
plt.show()

# %%
sns.barplot(x='sex',y='suicide_no',data=dataset)

# %%
sns.barplot(x='suicide_no',y='age',data=dataset)

# %%
sns.scatterplot(x='HDI_for_year', y='suicide_no',data=dataset)

# %%
sns.scatterplot(x='suicide_no', y='HDI_for_year', data=dataset)

# %%
sns.scatterplot(x='population', y='suicide_no',data=dataset)

# %%
sns.scatterplot(x='age', y='suicide_no',data=dataset)

# %%
sns.scatterplot(x='sex', y='suicide_no',data=dataset)

# %%
sns.scatterplot(x='country', y='suicide_no',data=dataset)

# %%
sns.scatterplot(x='year', y='suicide_no',data=dataset)

# %%
sns.scatterplot(x='population', y='age',data=dataset)

# %%
sns.scatterplot(x='population', y='sex',data=dataset)

# %%
sns.scatterplot(x='HDI_for_year', y='population',data=dataset)

# %%
sns.scatterplot(x='population', y='HDI_for_year',data=dataset)

# %%
df=pd.DataFrame(dataset)
plt.scatter(df.HDI_for_year,df.suicide_no)
plt.show()

# %%
df=pd.DataFrame(dataset)
plt.scatter(df.suicide_no,df.HDI_for_year)
plt.show()
